# %%
from langchain_core.prompts import PromptTemplate

# %%
PromptTemplate1 = PromptTemplate(
    template = "You are a helpful assistant.\nUser: {userInput}",
    input_variables= ['userInput']
)

# %%
PromptTemplate1.invoke({'userInput':'what is AI in short'})
# Out:
# StringPromptValue(text='You are a helpful assistant.\nUser: what is AI in short')

# %% [raw]
# Note : Prompt is just a input to the model , Based on the output Expectations we should customize the prompt
