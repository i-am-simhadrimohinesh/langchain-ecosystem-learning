# %%
from langchain_google_genai import GoogleGenerativeAI
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = GoogleGenerativeAI(model='gemini-2.5-flash')

# %%
result = model.invoke('what is meant by thermodynamics')

# %%
print(result)
# Out:
# **Thermodynamics** is a branch of physics that deals with **heat** and its relation to **other forms of energy and work**. It describes how thermal energy is converted to and from other forms of energy, and how it affects matter.
#
# At its core, thermodynamics seeks to understand:
#
# 1.  **Energy Transformations:** How energy moves and changes form (e.g., heat to mechanical work, chemical energy to heat).
# 2.  **Direction of Processes:** Why certain processes occur spontaneously (e.g., heat flows from hot to cold, not the other way around) and others do not.
# 3.  **Limits of Efficiency:** What are the fundamental limits to converting one form of energy into another (e.g., how efficient can an engine be)?
#
# It's based on a few fundamental principles, known as the **Laws of Thermodynamics**:
#
# *   **Zeroth Law:** Defines **temperature** and states that if two systems are each in thermal equilibrium with a third system, then they are in thermal equilibrium with each other. This allows for the concept of temperature measurement.
# *   **First Law:** The law of **conservation of energy**. It states that energy cannot be created or destroyed, only transformed from one form to another. In a closed system, the total energy remains constant. (ΔU = Q - W, where ΔU is the change in internal energy, Q is heat added to the system, and W is work done by the system).
# *   **Second Law:** Introduces the concept of **entropy**. It states that the total entropy (a measure of disorder or energy dispersal) of an isolated system can only increase over time, or remain constant in ideal cases. It explains why processes have a natural direction (e.g., heat flows from hot to cold, not cold to hot) and why perpetual motion machines are impossible.
# *   **Third Law:** States that the entropy of a system approaches a constant minimum value as the temperature approaches **absolute zero**. This implies that absolute zero (0 Kelvin or -273.15 °C) cannot be perfectly reached.
#
# **Key Concepts in Thermodynamics:**
#
# *   **System and Surroundings:** Defining the part of the universe under study (the system) and everything else (the surroundings).
# *   **State Variables:** Macroscopic properties that describe the state of a system (e.g., pressure, volume, temperature, internal energy, entropy).
# *   **Processes:** The changes a system undergoes as it moves from one state to another (e.g., isothermal, adiabatic, isobaric).
# *   **Equilibrium:** A state where the system's macroscopic properties are stable and not changing over time.
#
# **Why is Thermodynamics Important?**
#
# Thermodynamics is crucial for understanding and designing a vast array of technologies and natural phenomena, including:
#
# *   **Engines:** Car engines, jet engines, power plants (steam turbines).
# *   **Refrigeration and Air Conditioning:** How heat can be moved against its natural flow.
# *   **Chemical Reactions:** Predicting the spontaneity and equilibrium of reactions.
# *   **Material Science:** Phase transitions (melting, boiling).
# *   **Biology:** Energy metabolism in living organisms.
# *   **Cosmology:** Understanding the ultimate fate of the universe.
#
# In essence, thermodynamics provides a fundamental framework for understanding energy, its transformations, and the inherent directionality of physical and chemical processes.

# %%
import sys

print(sys.executable)
# Out:
# C:\Users\Mohinesh\Desktop\GitRepositories\langchain-ecosystem-learning\.venv\Scripts\python.exe
