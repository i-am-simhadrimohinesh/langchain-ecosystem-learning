# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatGoogleGenerativeAI(model='gemini-3.1-flash-lite')

# %%
result = model.invoke('Expain me about LangChain in short')

# %%
print(result.content[0]['text'])
# Out:
# **LangChain** is an open-source framework designed to make it easier to build applications powered by Large Language Models (LLMs) like GPT-4.
#
# Think of it as **"connective tissue"** that allows an AI model to interact with the outside world.
#
# Here are the four key things it does:
#
# 1.  **Chaining:** It allows you to link multiple actions together. For example: "Search Google for X" $\rightarrow$ "Summarize the results" $\rightarrow$ "Translate the summary into Spanish."
# 2.  **Data Retrieval (RAG):** It helps connect LLMs to your own private data (like PDFs, databases, or websites) so the AI can answer questions about specific information it wasn't originally trained on.
# 3.  **Memory:** LLMs are "stateless" (they forget everything after each prompt). LangChain provides tools to give them "short-term memory" so they can remember the context of a conversation.
# 4.  **Agents:** It allows the AI to act as an "agent" that can decide which tools to use. For example, if you ask "What is the weather in Tokyo?", the AI decides to use a weather API tool to get the answer rather than guessing.
#
# **In short:** If the LLM is the "brain," LangChain provides the **hands, eyes, and memory** that allow it to perform complex, real-world tasks.
